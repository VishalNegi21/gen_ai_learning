# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.3-70b-versatile" , streaming=True)

# %%
ques = "Explain Gen AI"

# %%
res = llm.invoke(ques)
print(res.content)
# Out:
# **Introduction to General Artificial Intelligence (Gen AI)**
#
# General Artificial Intelligence (Gen AI) refers to a type of artificial intelligence that possesses the ability to understand, learn, and apply knowledge across a wide range of tasks, similar to human intelligence. The term "general" in Gen AI indicates that it can perform any intellectual task that a human can, making it a more advanced and versatile form of AI compared to Narrow or Weak AI, which is designed to excel in a specific domain.
#
# **Key Characteristics of Gen AI:**
#
# 1. **Human-like Intelligence**: Gen AI aims to replicate human intelligence, enabling it to learn, reason, and apply knowledge in various contexts.
# 2. **Generalizability**: Gen AI can perform a broad range of tasks, from simple to complex, without being limited to a specific domain or function.
# 3. **Autonomy**: Gen AI can operate independently, making decisions and taking actions without human intervention.
# 4. **Self-Improvement**: Gen AI can learn from experience, adapt to new situations, and improve its performance over time.
# 5. **Reasoning and Problem-Solving**: Gen AI can reason, solve problems, and make decisions using a combination of logic, intuition, and creativity.
#
# **Current State of Gen AI:**
#
# While significant progress has been made in AI research, true Gen AI does not yet exist. Current AI systems, including those using deep learning and neural networks, are still narrow and specialized, lacking the generalizability and human-like intelligence of Gen AI.
#
# **Challenges in Developing Gen AI:**
#
# 1. **Complexity of Human Intelligence**: Replicating human intelligence is a daunting task, requiring a deep understanding of cognitive processes, neuroscience, and psychology.
# 2. **Scalability**: Gen AI requires significant computational resources, large datasets, and advanced algorithms to process and learn from vast amounts of information.
# 3. **Ethics and Safety**: Developing Gen AI raises concerns about ethics, safety, and potential risks, such as job displacement, bias, and unintended consequences.
#
# **Potential Applications of Gen AI:**
#
# 1. **Scientific Research**: Gen AI could accelerate scientific discovery, helping humans solve complex problems in fields like medicine, climate change, and space exploration.
# 2. **Education**: Gen AI could revolutionize education, providing personalized learning experiences, adaptive assessments, and intelligent tutoring systems.
# 3. **Healthcare**: Gen AI could improve healthcare outcomes by analyzing medical data, diagnosing diseases, and developing personalized treatment plans.
# 4. **Economy and Industry**: Gen AI could automate complex tasks, enhance productivity, and create new business opportunities, leading to significant economic growth.
#
# In conclusion, Gen AI has the potential to transform various aspects of our lives, but its development is still in its infancy. As researchers continue to advance AI capabilities, we can expect significant breakthroughs and innovations in the field, ultimately leading to the creation of more intelligent, autonomous, and beneficial AI systems.

# %%
res = llm.stream(ques)

# %%
for chunk in res:
    print(chunk.content , end=" ")
# Out:
#  ** Introduction  to  General  Artificial  Intelligence  ( Gen  AI )**
#
#  General  Artificial  Intelligence  ( Gen  AI ),  also  known  as  Strong  AI  or  Human -Level  AI ,  refers  to  a  type  of  artificial  intelligence  that  possesses  the  ability  to  understand ,  learn ,  and  apply  knowledge  across  a  wide  range  of  tasks ,  similar  to  human  intelligence .  The  term  " general "  in  Gen  AI  signifies  that  this  AI  system  can  perform  any  intellectual  task  that  a  human  can ,  without  being  limited  to  a  specific  domain  or  function .
#
#  ** Key  Characteristics  of  Gen  AI : **
#
#  1 .  ** Reason ing  and  Problem -S olving **:  Gen  AI  can  reason ,  solve  problems ,  and  make  decisions  like  humans ,  using  a  combination  of  logic ,  intuition ,  and  experience .
#  2 .  ** Knowledge  Representation **:  Gen  AI  can  represent  and  manipulate  knowledge  in  a  way  that  is  similar  to  human  cognition ,  using  concepts ,  relationships ,  and  ab stractions .
#  3 .  ** Learning  and  Adapt ation **:  Gen  AI  can  learn  from  experience ,  adapt  to  new  situations ,  and  improve  its  performance  over  time ,  much  like  humans  do .
#  4 .  ** Common  Sense **:  Gen  AI  possesses  common  sense ,  which  enables  it  to  understand  the  world  in  a  way  that  is  similar  to  human  intuition  and  experience .
#  5 .  ** Creat ivity **:  Gen  AI  can  generate  novel  solutions ,  ideas ,  and  products ,  much  like  human  creativity .
#
#  ** Types  of  Gen  AI : **
#
#  1 .  ** N arrow  or  Weak  AI **:  This  type  of  AI  is  designed  to  perform  a  specific  task ,  such  as  image  recognition ,  natural  language  processing ,  or  expert  systems .
#  2 .  ** General  or  Strong  AI **:  This  type  of  AI  is  designed  to  perform  any  intellectual  task  that  a  human  can ,  without  being  limited  to  a  specific  domain  or  function .
#  3 .  ** Super intelligence **:  This  type  of  AI  is  significantly  more  intelligent  than  the  best  human  minds ,  and  is  capable  of  solving  complex  problems  that  are  currently  uns olvable  by  humans .
#
#  ** Applications  of  Gen  AI : **
#
#  1 .  ** Robot ics  and  Autonomous  Systems **:  Gen  AI  can  be  used  to  control  robots  and  autonomous  systems ,  enabling  them  to  perform  complex  tasks  and  make  decisions  in  real -time .
#  2 .  ** Health care  and  Medicine **:  Gen  AI  can  be  used  to  diagnose  diseases ,  develop  personalized  treatment  plans ,  and  improve  patient  outcomes .
#  3 .  ** Finance  and  Economics **:  Gen  AI  can  be  used  to  analyze  financial  data ,  make  predictions ,  and  optimize  investment  strategies .
#  4 .  ** Education  and  Learning **:  Gen  AI  can  be  used  to  develop  personalized  learning  systems ,  adaptive  assessments ,  and  intelligent  tutoring  systems .
#
#  ** Ch allenges  and  Ris ks  of  Gen  AI : **
#
#  1 .  ** Job  Dis placement **:  Gen  AI  could  potentially  dis place  human  workers ,  particularly  in  industries  that  are  heavily  reliant  on  automation .
#  2 .  ** Bias  and  Fair ness **:  Gen  AI  can  perpet uate  biases  and  discrimination  if  it  is  trained  on  biased  data  or  designed  with  a  particular  worldview .
#  3 .  ** Security  and  Safety **:  Gen  AI  can  be  used  for  malicious  purposes ,  such  as  developing  autonomous  weapons  or  exploiting  vulnerabilities  in  critical  infrastructure .
#  4 .  ** Exist ential  Risk **:  Some  experts  believe  that  the  development  of  super int elligent  Gen  AI  could  pose  an  existential  risk  to  humanity ,  if  it  is  not  designed  with  safety  and  control  mechanisms .
#
#  ** Current  State  of  Gen  AI : **
#
#  While  significant  progress  has  been  made  in  developing  narrow  AI  systems ,  the  development  of  general  AI  is  still  an  active  area  of  research .  Currently ,  there  are  several  approaches  to  developing  Gen  AI ,  including :
#
#  1 .  ** Deep  Learning **:  This  approach  uses  neural  networks  to  learn  complex  patterns  and  relationships  in  data .
#  2 .  ** C ognitive  Architect ures **:  This  approach  uses  cognitive  models  to  simulate  human  cognition  and  provide  a  framework  for  integrating  multiple  AI  systems .
#  3 .  ** Hy brid  Appro aches **:  This  approach  combines  different  AI  techniques ,  such  as  symbolic  and  connection ist  AI ,  to  develop  more  general  and  flexible  AI  systems .
#
#  In  summary ,  Gen  AI  has  the  potential  to  revolution ize  numerous  industries  and  aspects  of  our  lives ,  but  it  also  poses  significant  challenges  and  risks  that  need  to  be  addressed  through  careful  research ,  design ,  and  development .
