# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
llm.invoke("Hello I am Vishal")
# Out:
# AIMessage(content="Hi Vishal! Happy to meet you. How’s your day going so far?  \n\nDo you have anything specific you'd like to chat about or need my help with today - perhaps you’re writing something, want to brainstorm some ideas, or just feeling curious? Let me know :)", additional_kwargs={}, response_metadata={'model': 'gemma3:1b', 'created_at': '2026-06-23T06:27:33.0915842Z', 'done': True, 'done_reason': 'stop', 'total_duration': 10669976100, 'load_duration': 3999575400, 'prompt_eval_count': 14, 'prompt_eval_duration': 356239000, 'eval_count': 61, 'eval_duration': 6308560000, 'logprobs': None, 'model_name': 'gemma3:1b', 'model_provider': 'ollama'}, id='lc_run--019ef329-7ab1-77d0-bcab-5585a90f53f8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 61, 'total_tokens': 75})
