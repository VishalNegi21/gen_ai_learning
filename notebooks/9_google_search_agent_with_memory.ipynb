# %%
from langchain_groq import ChatGroq
from langchain.agents import create_agent
from langchain_community.utilities import GoogleSerperAPIWrapper
from langgraph.checkpoint.memory import InMemorySaver
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_14788\3104436362.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import GoogleSerperAPIWrapper

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model=llm,
    tools=[search.run],
    system_prompt="You are an agent that can search answers for questions on google",
    checkpointer=InMemorySaver()
)

# %%
question = "Who secured rank 1 in Jee Mains 2026?"

# %%
res = agent.invoke(
    {"messages":[{"role":"user","content":question}]},
    {"configurable":{"thread_id":"1"}}
)

# %%
print(res["messages"][-1].content)
# Out:
# **Rank 1 in JEE Mains 2026**
# The All‑India Rank (AIR) 1 was secured by **Aarush Singhal** from Chandigarh, who achieved a perfect score of 300/300 (100 percentile) in the April 2026 session 2 exam.
#
# *Source:* Google search result – “Aarush Singhal bagged AIR 1 in JEE Main 2026.”

# %%
res = agent.invoke(
    {"messages":[{"role":"user","content":"from which coaching institute he was?"}]},
    {"configurable":{"thread_id":"1"}}
)

# %%
print(res["messages"][-1].content)
# Out:
# **Coaching institute:** **Sri Chaitanya Chandigarh**
#
# Aarush Singhal, who secured AIR 1 in JEE Mains 2026 (Session 2, April 2026), was training under the Sri Chaitanya coaching center in Chandigarh. The institute is frequently mentioned in news releases and social‑media posts celebrating his achievement.
